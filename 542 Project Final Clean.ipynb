# %%
import pandas as pd

# %%
westcoastracedata='https://github.com/NichMaue/Projects/raw/main/westcoastracedata.xlsx'

# %%
westcoastracedata=pd.read_excel(westcoastracedata)

# %%
westcoastracedata
# Out:
#              Area Name      Total  White Total  Black Total  AIAN Total  \
# 0                Adams   20150.00      18056.0       446.00     1109.00
# 1               Asotin   22520.01      21087.0       144.00      355.99
# 2               Benton  201799.99     181938.0      3378.00     2503.99
# 3               Chelan   78420.00      73391.0       510.01     1497.00
# 4              Clallam   76010.00      65939.0       791.00     4242.01
# ..                 ...        ...          ...          ...         ...
# 128     Wallowa County    7208.00       6890.0        33.00       68.00
# 129       Wasco County   26682.00      24271.0       215.00     1003.00
# 130  Washington County  601592.00     479049.0     15194.00     6827.00
# 131     Wheeler County    1332.00       1224.0         3.00       34.00
# 132     Yamhill County  107100.00      97848.0      1287.00     2148.00
#
#      Asian Total  NHOPI Total  Two or More Races Total       State
# ...

# %%
rename=['County', 'total_population','white_total', 'black_total', 'aian_total', 'asian_total', 'nhopi_total', 'multiracial_total','State']

# %%
westcoastracedata.columns[::]
# Out:
# Index(['Area Name', 'Total', 'White Total', 'Black Total', 'AIAN Total',
#        'Asian Total', 'NHOPI Total', 'Two or More Races Total', 'State'],
#       dtype='object')

# %%
dict(zip(westcoastracedata.columns[::], rename))
# Out:
# {'Area Name': 'County',
#  'Total': 'total_population',
#  'White Total': 'white_total',
#  'Black Total': 'black_total',
#  'AIAN Total': 'aian_total',
#  'Asian Total': 'asian_total',
#  'NHOPI Total': 'nhopi_total',
#  'Two or More Races Total': 'multiracial_total',
#  'State': 'State'}

# %%
westcoastracedata.rename(columns=dict(zip(westcoastracedata.columns[::], rename)),inplace=True)

# %%
westcoastracedata
# Out:
#                 County  total_population  white_total  black_total  \
# 0                Adams          20150.00      18056.0       446.00
# 1               Asotin          22520.01      21087.0       144.00
# 2               Benton         201799.99     181938.0      3378.00
# 3               Chelan          78420.00      73391.0       510.01
# 4              Clallam          76010.00      65939.0       791.00
# ..                 ...               ...          ...          ...
# 128     Wallowa County           7208.00       6890.0        33.00
# 129       Wasco County          26682.00      24271.0       215.00
# 130  Washington County         601592.00     479049.0     15194.00
# 131     Wheeler County           1332.00       1224.0         3.00
# 132     Yamhill County         107100.00      97848.0      1287.00
#
#      aian_total  asian_total  nhopi_total  multiracial_total       State
# 0       1109.00        287.0        11.00              241.0  Washington
# ...

# %%
westcoastracedata.to_csv('westcoastracedata.csv',index=False)

# %%
import re

# %%
import numpy as np

# %%
westcoastracedata.replace({County:np.''},inplace=True)
# Out:
#   File "<ipython-input-44-c69f336db737>", line 1
#     westcoastracedata.replace({County:np.''},inplace=True)
#                                          ^
# SyntaxError: invalid syntax
